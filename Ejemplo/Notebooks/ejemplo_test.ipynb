# %% [markdown]
# ## Ejemplo de como usar el Notebook para pruebas unitarias

# %% [markdown]
# #### primero se importan los módulos a probar. Ya que queremos comprobar si el código que hicimos funciona correctamente

# %%
from Módulos.extraction.pdf_extractor import extract_text_from_pdf
from Módulos.nlp.text_classifier import split_qa
# Out:
# Running cells with '.venv (Python 3.12.10)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/data/data/com.termux/files/home/fuzzmap/.venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# #### 1. Extraer texto

# %%
texto = extract_text_from_pdf("data/Habilidades_Vida/ejemplo.pdf")
print(texto)

# %% [markdown]
# #### 2. Separar preguntas y respuestas

# %%
qa = split_qa(texto)
print("Preguntas encontradas:", qa)

# %% [markdown]
# #### 3. Assert simple

# %%
assert len(qa) > 0, "No se extrajo ninguna pregunta."
