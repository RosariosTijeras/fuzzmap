# %% [markdown]
# #### prueba para saber si el auth.py es capaz de leer el json y escribir en el

# %%
from Modulos.ui.auth import _cargar_usuarios, _guardar_usuarios

# preparamos el usuario de prueba
prueba = {
    "juan":{
        "password":"1234",
        "nombre":"Juan Carlos",
        "apellido":"Pérez López",
        "edad":25,
        "sexo":"Masculino",
    }
}

# guardamaos el usuario de prueba en el archivo
_guardar_usuarios (prueba)

# cargamos el usuario de prueba
usuario = _cargar_usuarios ()
# comprobamos que el usuario se ha cargado correctamente
print(usuario)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#       4 prueba = {
#       5     "juan":{
#       6         "password":"1234",
#    (...)     11     }
#      12 }
#      14 # guardamaos el usuario de prueba en el archivo
# ---> 15 _guardar_usuarios (prueba)
#      17 # cargamos el usuario de prueba
#      18 usuario = _cargar_usuarios ()
#
# NameError: name '_guardar_usuarios' is not defined
